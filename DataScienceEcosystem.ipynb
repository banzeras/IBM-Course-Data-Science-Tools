# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# ![Screenshot from 2023-10-13 10-30-59.png](attachment:a3b1b557-8693-44e5-885e-280889998f60.png)

# %% [markdown]
# ![Screenshot from 2023-10-13 10-33-34.png](attachment:480c0718-7ca7-48b3-bc5c-528a0301934c.png)

# %% [markdown]
# ![2-title.png](attachment:50eb2cbd-41a1-4ff2-86b2-a0833fb4e4df.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![Screenshot from 2023-10-13 10-33-42.png](attachment:c0a759af-cd7c-4295-8a99-7f3a27905b52.png)![3-intro.png](attachment:94a386ee-0cce-4dd5-a335-3745b7911da5.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# + List popular languages for Data Science
# + List popular libraries for Data Science
# + Examples of markdown commands

# %% [markdown]
# ![Screenshot from 2023-10-13 10-33-48.png](attachment:e99df0a5-cb88-4d09-8756-e7041e2faa55.png)

# %% [markdown]
# ![4-dslanguages.png](attachment:aa69daef-7c0b-4287-8df0-3dc6dd24d81e.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Scala
# 4. Rust

# %% [markdown]
# ![Screenshot from 2023-10-13 10-33-53.png](attachment:a2e5896f-419f-44d4-abfb-92cdfe2c94b4.png)

# %% [markdown]
# ![5-dslibraries.png](attachment:7e2d814d-e3e9-466b-a354-e52fcb046ad9.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Sci-kitlearn
# 3. Tensorflow
# 4. Keras
# 5. PyTorch
# 6. Polars
# 7. Statsmodels
# 8. xGboost
# 9. Caret

# %% [markdown]
# ![Screenshot from 2023-10-13 10-33-58.png](attachment:c5857712-f4fc-45e0-ab20-ebf283354dd5.png)

# %% [markdown]
# ![6-dstools.png](attachment:82196e0a-c6c4-42f3-92b1-3eac558f072d.png)

# %% [markdown]
# | Data Science Tools |
# ----------------------
# |Google Collab|
# |Watson Studio|
# |R Studio|
# |Visual Studio Code|

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-04.png](attachment:0a5b85cd-4156-4700-81d4-cc7d64a912cd.png)

# %% [markdown]
# ![7-introarithmetic.png](attachment:5a1ed495-190f-4d93-bfe3-21c4139d565b.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-08.png](attachment:b12fc140-bf90-4051-968f-d621845fe5e0.png)

# %% [markdown]
# ![8-multiplyaddintegers.png](attachment:f8a161b8-bbcf-40d0-bcfd-f9f9964140e8.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-13.png](attachment:07ef37f3-6cc7-47a4-96db-5f944b78dd6c.png)

# %% [markdown]
# ![9-hourstominutes.png](attachment:783d43c3-badb-4fe4-8405-a5947a8e3683.png)

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-18.png](attachment:34f36ace-7616-46b9-8d2d-2851f99f9537.png)

# %% [markdown]
# ![10-objectives.png](attachment:ff7e5303-3d4e-4891-8193-251d7f2c5794.png)

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-24.png](attachment:71fba410-d4f7-4664-b7d4-06189bf7bf5b.png)

# %% [markdown]
# ![11-authordetails.png](attachment:b742f7aa-a848-468f-b5a0-59af855db4b2.png)

# %% [markdown]
# ## Author
# Emanuel Elias

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-32.png](attachment:33d37b14-f6d5-423f-9471-a7f9fe3d7680.png)

# %%
[](Link to repository)

# %% [markdown]
# ![Screenshot from 2023-10-13 10-34-44.png](attachment:04584c0b-450c-4aac-8651-d88736deec3c.png)
